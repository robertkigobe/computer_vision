# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
pic = Image.open('norumbega.png')

# %%
type(pic)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
pic_arr.shape
# Out:
# (2187, 3280, 3)

# %%
plt.imshow(pic_arr)

# %%
# make a copy of the image to do red actions
pic_red = pic_arr.copy()

# %%
pic_red.shape
# Out:
# (2187, 3280, 3)

# %%
#R =0,G=1,B=2. lets zerro out the other channels

plt.imshow(pic_red[:,:,0])

# %%
#shows the picture in gray scale
plt.imshow(pic_red[:,:,0],cmap='gray')

# %%
#shows that all the values are between 0-255
pic_red[:,:,0]
# Out:
# array([[ 87,  78,  74, ..., 141, 112, 100],
#        [ 87,  78,  74, ..., 155, 125, 101],
#        [ 93,  88,  78, ..., 162, 137, 109],
#        ...,
#        [135, 166, 168, ..., 218, 217, 216],
#        [117, 147, 166, ..., 217, 216, 216],
#        [100, 129, 150, ..., 216, 216, 217]], dtype=uint8)

# %%
pic_red[:,:,0].shape
# Out:
# (2187, 3280)

# %%
#pic red still contains the 3 channels, so lets zero them out
pic_red.shape
# Out:
# (2187, 3280, 3)

# %%
#remove green
pic_red[:,:,1] = 0

# %%
#only red and blue remain hence more purple
plt.imshow(pic_red)

# %%
#remove blue
pic_red[:,:,2] = 0

# %%
#only red remains
plt.imshow(pic_red)
